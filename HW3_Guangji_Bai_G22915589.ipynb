# %% [markdown]
# # Homework 3

# %% [markdown]
# ### Step 1: Import necessary libraries

# %%
import nltk.data
from os import listdir
from os.path import isfile, join
from nltk.util import bigrams 
from nltk.tokenize import TreebankWordTokenizer
sentence_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
treebank_tokenizer = TreebankWordTokenizer()

# %%
# This will be the corpus we work from
from nltk.corpus import reuters

# %%
# I will assume you are using Spacy as a default entity recognizer.
import spacy

# %%
# note, the model load can be odd. In some instances your model might have the full name or the short name here.
# if you run into issues here, check the spacy model page at https://spacy.io/usage/models
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Step 2: FIll in the following function to extract the entity, document id, and relevant sentence text from the input

# %%
def extract_entities(doc_id, doc_text):
    analyzed_doc = nlp(doc_text)
    
    doc_persons = {}
    doc_locations = {}
    
    for entity in analyzed_doc.ents:
        if entity.text.strip() != "":
            # The .label_ property will provide information on the type of entity tagged
            #print(" -> ", entity.label_)
            # The .text property will display the actual text of the entity in the text
            #print("->", entity.text.strip(), "<-")
            # You can also access the sentence that the entity is contained in by using the .sent property
            # inside the sentence you can then use the .text property
            #print("->", entity.sent.text, "<-")
            
            # add the relevant document id and sentence to the entity record
            if entity.label_ == "PERSON":
                if entity.text.strip() not in doc_persons.keys():
                    doc_persons[entity.text.strip()] = [doc_id,[entity.sent.text]]
                else:
                    doc_persons[entity.text.strip()][1].append(entity.sent.text)
                    
            if entity.label_ in ["LOC","GPE"]: # Here, I considered both geopolitical and non_geopolitical locations.
                if entity.text.strip() not in doc_locations.keys():
                    doc_locations[entity.text.strip()] = [doc_id,[entity.sent.text]]
                else:
                    doc_locations[entity.text.strip()][1].append(entity.sent.text)
            
    return doc_persons, doc_locations

# %% [markdown]
# ### Step 3: Adjust the following code to run the document entity extraction function

# %% [markdown]
# ### Also, add the entity records you are constructing to your master list of entities

# %%
num_docs = len(reuters.fileids())

# these two dictionaries will incorporate all the referneces to 
combined_persons = {}
combined_locations = {}

for doc_id in reuters.fileids(): 
    # this doc_text variable will give you a text version of the news article. This could be tokenized.
    persons, locations = extract_entities(doc_id, reuters.open(doc_id).read())
    
    # you will need to write something here to put the persons and locations found in a document into the 
    # combined_persons and combined_locations dictionaries.
    # here you will need to consider how to extend the values already in the dictionaries
    # maybe something like:
    
    for person in persons.keys():
        if person not in combined_persons.keys():
            combined_persons[person] = [persons[person]]
        else:
            combined_persons[person].append(persons[person])
            
    for location in locations.keys():
        if location not in combined_locations.keys():
            combined_locations[location] = [locations[location]]
        else:
            combined_locations[location].append(locations[location])

# %% [markdown]
# ### Step4: Fill in the following method to look through the content of an entity dictionary to determine the most popular based on number of mentions

# %%
import operator

# %%
# now that we have the text associated with the entities, 
# you will want to focus on the 500 top entities in each category
# Identify the top 500 entities by the count of their occurrences

def find_most_popular_entities(entity_dictionary):
    list_of_dictionary_keys_with_most_mentions = []
    temp_dict = {}
    # sort through the entities in the dictionary by the number of sentences
    for entity_key in entity_dictionary.keys():
        count = 0
        for doc in entity_dictionary[entity_key]:
            count += len(doc[1])
        temp_dict[entity_key] = count
    
    sorted_temp_dict = sorted(temp_dict.items(), key=operator.itemgetter(1), reverse=True)
    
    for item in sorted_temp_dict[:500]:
        list_of_dictionary_keys_with_most_mentions.append(item[0])
    
    return list_of_dictionary_keys_with_most_mentions

# %% [markdown]
# ### Step 5: Now invoke your top entity mention finder

# %%
# simply get the top persons and locations
top_persons = find_most_popular_entities(combined_persons)
top_locations = find_most_popular_entities(combined_locations)

# %% [markdown]
# ### Step 6: Analyze the most popular entities to determine what words they most frequently occur with

# %%
from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))
from nltk.stem.porter import *
porter_stemmer = PorterStemmer()

# %%
# This function is used for identifying all possible noise words
min_token_length = 2

def isNoise(token):     
    is_noise = False
    if porter_stemmer.stem(token) in stopWords:
        is_noise = True
    elif len(token.strip()) < min_token_length:
        is_noise = True
    elif re.findall(r"\,|\`|\'", token):
        is_noise = True
    return is_noise

# %%
from collections import Counter 
  
def most_frequent(List): 
    occurence_count = Counter(List) 
    return [occurence_count.most_common(4)[0],occurence_count.most_common(4)[1],
            occurence_count.most_common(4)[2],occurence_count.most_common(4)[3]]

# %%
# use these two dictionaries to store the most frequent terms associated with the entities
person_most_popular_terms = {}
location_most_popular_terms = {}

# finally, now find the most frequent tokens associated with the entities
for person in top_persons:
    temp_words = []
    for doc in combined_persons[person]:
        for sent in doc[1]:
            temp_words += treebank_tokenizer.tokenize(str(sent))
    temp_words  = [word.strip("\\") for word in temp_words if not isNoise(word)] 
    person_most_popular_terms[person] = []
    for pair in most_frequent(temp_words):  
        if (pair[0] != person) & (len(person_most_popular_terms[person]) < 3):
            person_most_popular_terms[person].append(pair)
    
for location in top_locations:
    temp_words = []
    for doc in combined_locations[location]:
        for sent in doc[1]:
            temp_words += treebank_tokenizer.tokenize(sent)
    temp_words  = [word.strip("\\") for word in temp_words if not isNoise(word)] 
    location_most_popular_terms[location] = []
    for pair in most_frequent(temp_words):
        if (pair[0] != location) & (len(location_most_popular_terms[location]) < 3):
            location_most_popular_terms[location].append(pair)

# %% [markdown]
# ### Step 7: Present your results of the most popular entities and their associated terms

# %%
# My way of finding the associated terms is to find the top 3 most frequent terms which cooccur with the certain entity in the same sentences.
print(person_most_popular_terms)
# Out:
# {'Oper': [('vs', 1377), ('cts', 853), ('loss', 739)], 'Record': [('cts', 809), ('vs', 411), ('April', 405)], 'Reagan': [('said', 171), ('U.S.', 140), ('President', 124)], 'Baker': [('said', 115), ('was', 52), ('Hughes', 35)], 'LOSS': [('loss', 263), ('vs', 172), ('cts', 139)], '4TH': [('vs', 196), ('cts', 147), ('QTR', 132)], 'Lawson': [('said', 78), ('was', 28), ('would', 24)], 'NET': [('vs', 253), ('cts', 176), ('Shr', 111)], 'Avg': [('vs', 251), ('mln', 163), ('billion', 129)], 'James Baker': [('James', 95), ('Treasury', 94), ('Baker', 93)], 'PAYOUT': [('cts', 57), ('SETS', 32), ('lt', 30)], 'Qtr': [('vs', 134), ('cts', 85), ('Shr', 45)], 'Poehl': [('said', 22), ('would', 15), ('rate', 14)], 'BAKER': [('TREASURY', 38), ('SAYS', 28), ('U.S.', 20)], 'Yeutter': [('said', 48), ('U.S.', 24), ('trade', 16)], 'Revs': [('vs', 121), ('loss', 72), ('mln', 54)], 'Clayton Yeutter': [('U.S.', 61), ('Trade', 45), ('Yeutter', 43)], 'Kiichi Miyazawa': [('Finance', 41), ('Minister', 38), ('Kiichi', 38)], 'Allegheny': [('said', 21), ('company', 10), ('dlrs', 10)], 'Johnson': [('said', 33), ('has', 13), ('Tate', 10)], 'Brown': [('AFG', 31), ('Wagner', 25), ('Inc', 23)], 'DIVIDEND': [('cts', 38), ('April', 16), ('vs', 16)], 'TONNES': [('EC', 17), ('LICENCES', 14), ('BARLEY', 11)], 'Icahn': [('USAir', 18), ('said', 12), ('TWA', 11)], 'Crazy Eddie': [('Eddie', 53), ('Crazy', 51), ('said', 17)], 'Yasuhiro Nakasone': [('Prime', 31), ('Yasuhiro', 31), ('Minister', 30)], 'Williams': [('mln', 15), ('Norcros', 13), ('said', 12)], 'Prev Wk': [('nil', 69), ('Prev', 32), ('Wk', 31)], 'Bass': [('said', 18), ('group', 11), ('pct', 11)], 'Reuter': [('said', 7), ('mln', 7), ('correspondents', 6)], 'REAGAN': [('SAYS', 22), ('TO', 14), ('U.S.', 11)], '3RD': [('vs', 41), ('cts', 34), ('QTR', 24)], '3RD QTR FEB': [('vs', 40), ('cts', 29), ('3RD', 27)], 'Baldrige': [('said', 19), ('U.S.', 11), ('told', 8)], 'Nigel Lawson': [('Chancellor', 26), ('Exchequer', 26), ('Nigel', 26)], 'Miyazawa': [('says', 14), ('said', 11), ('nations', 10)], 'Subroto': [('said', 19), ('Energy', 11), ('Minister', 10)], 'Richard Lyng': [('Agriculture', 25), ('Richard', 25), ('Lyng', 25)], 'Karl Otto Poehl': [('Bundesbank', 26), ('Karl', 25), ('Otto', 25)], 'Caspar Weinberger': [('Secretary', 28), ('Caspar', 24), ('Weinberger', 24)], 'Dauster': [('said', 18), ('quotas', 7), ('coffee', 7)], 'Commenting': [('said', 18), ('year', 6), ('billion', 6)], 'Reynolds': [('said', 18), ('company', 8), ('sale', 6)], 'Heller': [('said', 18), ('would', 12), ('was', 5)], 'Edouard Balladur': [('Finance', 25), ('Minister', 23), ('Edouard', 22)], 'BILL': [('U.S.', 20), ('TRADE', 10), ('said', 4)], 'Lukman': [('said', 17), ('OPEC', 9), ('oil', 9)], 'Becor': [('said', 12), ('dlrs', 12), ('Lynch', 10)], 'Buenos Aires': [('Buenos', 21), ('Aires', 21), ('mm', 17)], 'Balladur': [('pct', 17), ('said', 11), ('target', 7)], 'Chirac': [('said', 11), ('France', 5), ('would', 5)], 'Conrac': [('said', 15), ('IV', 9), ('company', 8)], 'Paul Volcker': [('Paul', 20), ('Volcker', 19), ('Federal', 18)], 'Malcolm Baldrige': [('Secretary', 24), ('U.S.', 20), ('Commerce', 20)], 'Clark': [('said', 14), ('trade', 7), ('group', 5)], 'Dart': [('said', 16), ('Supermarkets', 12), ('SGL', 9)], 'CCC': [('U.S.', 19), ('said', 17), ('Credit', 16)], 'Gerhard Stoltenberg': [('Finance', 23), ('Minister', 18), ('Gerhard', 18)], 'Rotterdam': [('sector', 6), ('union', 6), ('Dutch', 5)], 'Statoil': [('field', 15), ('lt', 11), ('A/S', 9)], 'Darman': [('Baker', 11), ('said', 6), ('would', 4)], 'M-2': [('pct', 15), ('M-3', 10), ('said', 9)], 'Clayton': [('U.S.', 23), ('Yeutter', 17), ('Trade', 16)], 'Satoshi Sumita': [('Japan', 19), ('Satoshi', 17), ('Sumita', 17)], 'Samjens': [('Burlington', 13), ('would', 8), ('lawyers', 6)], 'Sumita': [('says', 11), ('said', 9), ('dollar', 8)], 'N.Z. Dlrs': [('N.Z.', 17), ('Dlrs', 17), ('billion', 16)], 'Richard': [('Agriculture', 16), ('Secretary', 16), ('U.S.', 14)], '3RD QTR': [('lt', 16), ('3RD', 16), ('QTR ...

# %%
print(location_most_popular_terms)
# Out:
# {'U.S.': [('said', 1861), ('trade', 575), ('dlrs', 500)], 'Shr': [('vs', 2889), ('cts', 1932), ('loss', 1854)], 'Japan': [('said', 648), ('U.S.', 434), ('trade', 322)], 'U.K.': [('said', 142), ('MONEY', 103), ('MARKET', 102)], 'Brazil': [('said', 224), ('mln', 99), ('dlrs', 78)], 'the United States': [('United', 411), ('States', 410), ('said', 227)], 'Paris': [('said', 182), ('accord', 93), ('nations', 90)], 'Canada': [('said', 147), ('U.S.', 93), ('pct', 70)], 'China': [('said', 169), ('tonnes', 78), ('mln', 64)], 'Washington': [('said', 140), ('U.S.', 90), ('trade', 84)], 'London': [('said', 145), ('market', 52), ('was', 44)], 'West Germany': [('West', 280), ('Germany', 277), ('said', 123)], 'New York': [('New', 305), ('York', 282), ('said', 157)], 'Taiwan': [('U.S.', 150), ('said', 115), ('billion', 91)], 'Iran': [('said', 150), ('Gulf', 71), ('U.S.', 67)], 'Britain': [('said', 101), ('Japan', 77), ('France', 65)], 'Gulf': [('said', 126), ('U.S.', 83), ('oil', 58)], 'JAPAN': [('Japan', 74), ('TO', 70), ('said', 62)], 'Tokyo': [('said', 104), ('Japan', 63), ('yen', 47)], 'France': [('said', 76), ('Britain', 64), ('Germany', 60)], 'Indonesia': [('said', 88), ('oil', 67), ('palm', 33)], 'Ecuador': [('said', 93), ('oil', 72), ('pipeline', 56)], 'Australia': [('said', 92), ('pct', 48), ('Ltd', 40)], 'Europe': [('said', 75), ('U.S.', 43), ('mln', 28)], 'Nine': [('vs', 522), ('cts', 233), ('Shr', 172)], 'Texas': [('said', 82), ('dlrs', 41), ('lt', 30)], 'U.S': [('said', 63), ('trade', 46), ('U.S.', 43)], 'Italy': [('said', 71), ('pct', 35), ('France', 33)], 'the Soviet Union': [('Soviet', 150), ('Union', 140), ('said', 73)], 'Saudi Arabia': [('Saudi', 138), ('Arabia', 135), ('said', 74)], 'South Korea': [('South', 119), ('Korea', 118), ('said', 53)], 'Iraq': [('said', 61), ('Iran', 42), ('mln', 28)], 'Avg': [('vs', 234), ('mln', 197), ('Revs', 67)], 'Malaysia': [('said', 66), ('pct', 28), ('oil', 27)], 'India': [('said', 59), ('trade', 27), ('mln', 26)], 'Kuwait': [('said', 46), ('U.S.', 38), ('oil', 32)], 'Colombia': [('said', 49), ('coffee', 43), ('export', 27)], 'Spain': [('said', 40), ('pct', 33), ('mln', 29)], 'USSR': [('U.S.', 51), ('tonnes', 51), ('mln', 39)], 'CANADA': [('PCT', 48), ('U.S.', 28), ('Canada', 24)], 'California': [('said', 56), ('lt', 22), ('mln', 19)], 'Moscow': [('said', 47), ('wheat', 39), ('Soviet', 27)], 'Hong Kong': [('Hong', 97), ('Kong', 96), ('said', 57)], 'Venezuela': [('said', 47), ('oil', 36), ('Ecuador', 35)], 'Thailand': [('said', 49), ('tonnes', 35), ('mln', 19)], 'Singapore': [('said', 39), ('pct', 23), ('dlrs', 21)], 'Turkey': [('said', 33), ('Greece', 18), ('mln', 18)], 'Philippines': [('said', 43), ('mln', 19), ('was', 12)], 'The United States': [('United', 74), ('States', 72), ('said', 38)], 'CHINA': [('China', 37), ('TO', 21), ('said', 18)], 'United States': [('United', 72), ('States', 70), ('said', 35)], 'South Africa': [('South', 81), ('Africa', 74), ('said', 39)], 'Chicago': [('said', 38), ('pct', 26), ('shares', 16)], 'Mexico': [('said', 32), ('Ecuador', 13), ('Brazil', 12)], 'Norway': [('said', 33), ('oil', 26), ('lt', 18)], 'New Zealand': [('New', 70), ('Zealand', 70), ('said', 29)], 'Greece': [('said', 30), ('Turkey', 18), ('tonnes', 16)], 'Netherlands': [('said', 26), ('tonnes', 25), ('West', 24)], 'Argentina': [('said', 32), ('U.S.', 26), ('tonnes', 15)], 'Egypt': [('said', 36), ('tonnes', 27), ('U.S.', 14)], 'Pakistan': [('said', 27), ('mln', 19), ('tonnes', 18)], 'Revs': [('vs', 144), ('mln', 57), ('cts', 55)], 'Belgium': [('tonnes', 17), ('said', 17), ('West', 16)], 'Peru': [('said', 26), ('year', 10), ('dlrs', 10)], 'Houston': [('said', 40), ('lt', 17), ('Inc', 15)], 'Ohio': [('said', 37), ('Corp', 15), ('company', 12)], 'Florida': [('said', 38), ('Corp', 12), ('lt', 12)], 'Sweden': [('said', 25), ('lt', 24), ('pct', 18)], 'Bonn': [('said', 23), ('West', 14), ('German', 11)], 'Portugal': [('said', 24), ('pct', 22), ('EC', 17)], 'Germany': [('said', 23), ('would', 16), ('Japan ...

# %% [markdown]
# ### Output Analysis

# %% [markdown]
# ##### From the output above, we can see all top 500 popular persons and locations in Reuters with their top 3 frequently associated terms. Despite little number of meaningless words like "said", "it", etc, the majority of the associated terms are informatically useful. In addition, we can see there is strong association between popular persons and locations, which leads me to choose the first one in the Extra Credit questions.

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# ### Determine which persons and locations most frequently occur in the same sentences.

# %%
# Here, I want to store all possible occurred locations associated with a person and vice versa.
locations_associated_with_persons = {}
persons_associated_with_locations ={}

for person in person_most_popular_terms.keys():
    locations_associated_with_persons[person] = []
    all_sentences = []
    for doc in combined_persons[person]:
        for sent in doc[1]:
            all_sentences.append(sent)
    analyzed_all_sents = nlp(str(all_sentences))
    for entity in analyzed_all_sents.ents:
        if entity.text.strip() != "":
            if entity.label_ in ["LOC","GPE"]:
                locations_associated_with_persons[person].append(entity.text.strip())
                
for location in location_most_popular_terms.keys():
    persons_associated_with_locations[location] = []
    all_sentences = []
    for doc in combined_locations[location]:
        for sent in doc[1]:
            all_sentences.append(sent)
    analyzed_all_sents = nlp(str(all_sentences))
    for entity in analyzed_all_sents.ents:
        if entity.text.strip() != "":
            if (entity.label_ == "PERSON") & (entity.text.strip()!= '\\n\\n'):
                persons_associated_with_locations[location].append(entity.text.strip())

# %%
# Find out the most frequently cooccurred location with a person and vice versa.
most_freq_locations_associated_with_persons = {}
most_freq_persons_associated_with_locations = {}

for person in locations_associated_with_persons.keys():
    occurence_count = Counter(locations_associated_with_persons[person])
    if len(occurence_count.most_common(1)) > 0:
        most_freq_locations_associated_with_persons[person] = occurence_count.most_common(1)[0]
    
for location in persons_associated_with_locations.keys():
    occurence_count = Counter(persons_associated_with_locations[location])
    if len(occurence_count.most_common(1)) > 0:
        most_freq_persons_associated_with_locations[location] = occurence_count.most_common(1)[0]

# %%
most_freq_locations_associated_with_persons
# Out:
# {'Oper': ('dlrs\\n', 221),
#  'Record': ('Mthly', 18),
#  'Reagan': ('U.S.', 99),
#  'Baker': ('U.S.', 15),
#  'LOSS': ('Shr', 84),
#  '4TH': ('Shr', 44),
#  'Lawson': ('the United States', 5),
#  'NET': ('Shr', 54),
#  'Avg': ('dlrs\\n', 19),
#  'James Baker': ('U.S.', 34),
#  'PAYOUT': ('Qtly', 4),
#  'Qtr': ('Shr', 4),
#  'Poehl': ('and\\n', 4),
#  'BAKER': ('U.S.', 18),
#  'Yeutter': ('U.S.', 16),
#  'Revs': ('dlrs\\n', 19),
#  'Clayton Yeutter': ('U.S.', 36),
#  'Kiichi Miyazawa': ('Japan', 13),
#  'Allegheny': ('Sunter', 1),
#  'Johnson': ('U.S.', 4),
#  'Brown': ('dlrs\\n', 1),
#  'DIVIDEND': ('HIKES', 1),
#  'TONNES': ('U.S.', 9),
#  'Icahn': ('Piedmont', 3),
#  'Crazy Eddie': ('Crazy Eddie', 4),
#  'Yasuhiro Nakasone': ('Japan', 11),
#  'Williams': ('Norcros', 2),
#  'Prev Wk': ('E.O.A', 4),
#  'Bass': ('Texas', 5),
#  'Reuter': ('Japan', 2),
#  'REAGAN': ('U.S.', 11),
#  '3RD': ('Shr', 10),
#  '3RD QTR FEB': ('Shr', 4),
#  'Baldrige': ('U.S.', 9),
#  'Nigel Lawson': ('U.K.', 8),
#  'Miyazawa': ('Japan', 4),
#  'Subroto': ('Indonesia', 3),
#  'Richard Lyng': ('U.S.', 18),
#  'Karl Otto Poehl': ('West Germany', 3),
#  'Caspar Weinberger': ('U.S.', 19),
#  'Dauster': ('Brazil', 6),
#  'Commenting': ('Japan', 3),
#  'Reynolds': ('a\\n', 1),
#  'Heller': ('France', 1),
#  'Edouard Balladur': ('dollar."\\n', 1),
#  'BILL': ('U.S.', 10),
#  'Lukman': ('Nigeria', 3),
#  'Becor': ('Greenwich', 2),
#  'Buenos Aires': ('Cordoba', 6),
#  'Balladur': ('U.S.', 3),
#  'Chirac': ('France', 3),
#  'Conrac': ('Mark IV\\n', 1),
#  'Paul Volcker': ('U.S.', 2),
#  'Malcolm Baldrige': ('U.S.', 13),
#  'Clark': ('Canada', 3),
#  'Dart': ('Dayton Hudson', 1),
#  'CCC': ('U.S.', 13),
#  'Gerhard Stoltenberg': ('West Germany', 2),
#  'Rotterdam': ('Rotterdam', 2),
#  'Statoil': ('Norway', 4),
#  'Darman': ('U.S.', 4),
#  'M-2': ('Slifer', 2),
#  'Clayton': ('U.S.', 9),
#  'Satoshi Sumita': ('Japan', 4),
#  'Samjens': ('Burlington', 3),
#  'Sumita': ('Japan', 2),
#  'N.Z. Dlrs': ('N.Z.', 1),
#  'Richard': ('U.S.', 11),
#  '3RD QTR': ('Shr', 2),
#  'Shr': ('Shr', 9),
#  'Resorts': ('Atlantic City', 2),
#  'Huckaby': ('U.S.', 3),
#  'Pickens': ('U.S.', 2),
#  'Ecu': ('Belgium', 4),
#  'Allegis': ('San Francisco', 2),
#  'Balao': ('Ecuador', 9),
#  'SELLS': ('Los Angeles', 1),
#  'Nazer': ('Saudi Arabia', 6),
#  'Jorio Dauster': ('Brazil', 6),
#  'Simon': ('Schuster', 3),
#  'Herrington': ('U.S.', 5),
#  'Kim': ("South Korea's", 3),
#  'Standard': ('the Gulf of Mexico', 1),
#  'Jardine Matheson': ('Japan.\\n', 1),
#  'Donald Trump': ('New York', 3),
#  'Marlin Fitzwater': ('U.S.', 3),
#  'Volcker': ('Venice', 1),
#  'Purolator': ('Purolator', 1),
#  'Bill': ('U.K.', 12),
#  'Howard': ('Japan', 3),
#  'Margaret Thatcher': ('Britain', 3),
#  'Bangemann': ('institutes\\', 1),
#  'Harcourt': ('U.S.', 2),
#  'Paul\n  Volcker': ('U.S.', 4),
#  'Morgan': ('Brazil', 2),
#  'Dominion': ('Burlington', 2),
#  'George Shultz': ('U.S.', 16),
#  'Hernandez Grisanti': ('Ecuador', 6),
#  'Maekawa': ('the\\n', 2),
#  'Dudley Taft': ('Rhode Island', 1),
#  'Gaviria': ('Colombia', 6),
#  'Sorghum': ('Cordoba', 1),
#  '3RD QTR JAN 31': ('Shr', 4),
#  'Domes Use': ('Exports        Nil', 1),
#  'Sullivan': ('Vancouver', 4),
#  'Royex': ('Corona', 5),
#  'Nakasone': ('Japan', 2),
#  'Shultz': ('U.S.', 4),
#  'Nigel': ('U.K.', 3),
#  'Suharto': ('Indonesia', 4),
#  'Daniel Amstutz': ('U.S.', 3),
#  'John Herrington': ('U.S.', 4),
#  'EPAC': ('Portugal', 5),
#  'Corazon Aquino': ('Manila', 2),
#  'Fitzwater': ('the United States', 2),
#  'Lago Agrio': ('Ecuador', 8),
#  'Fahd': ('Saudi Arabia', 6),
#  'ASSISTANCE': ('U.K.', 8),
#  'Jim Wright': ('Texas', 5),
#  'Dan Glickman': ('dlrs\\n', 1),
#  'STAKE': ('Santa Monica,\\n', 2),
#  'Ali': ('Iraq', 3),
#  'Jacques Chirac': ('U.S.', 2),
#  'Stoltenberg': ('Poehl', 2),
#  'Swire': ('and\\n', 1),
#  'DOLLAR': ('U.S.', 2),
#  'Ind Ttl-F': ('E.O.A', 1),
#  'Rice': ('U.S.', 3),
#  'McCarthy': ('the\\n', 2),
#  'RISE': ('U.K.', 2),
#  'Cyclops': ('Pittsburgh', 2),
#  'Hisham Nazer': ('Riyadh', 2),
#  'Glickman': ('do\\n', 1),
#  'Leigh-Pemberton': ('U.K.', 1),
#  'Shr 24': ('Shr', 7),
#  'Fernando Santos Alvite': ('Ecuador', 8),
#  'Roderick': ('U.S.', 2),
#  'De Croo': ('Washington', 2),
#  'TMOC': ('year,\\n', 1),
#  'Dole': ('U.S.', 1),
#  'SUBROTO': ('SUBROTO', 1),
#  'mm': ('to\\n  31 mm', 2),
#  'Asher Edelman': ('New York', 5),
#  'Michael Wilson': ('Canada', 2),
#  'Het Comite': ('Luxembourg', 2),
#  'Azpurua': ('a\\n', 2),
#  'Lee': ('Bramalea', 1),
#  'Greenspan': ('U.S.', 2),
#  'Rilwanu Lukman': ('Vienna', 2),
#  '6.4': ('Cuba', 1),
#  'Kahan': ('U.S.', 2),
#  'Weinberger': ('U.S.', 5),
#  'Carl Icahn': ('a\\n', 1),
#  'Bra Kanon': ('Bra Kanon', 1),
#  'Richard Gephardt': ('Japan', 5),
#  'Kansai': ('U.S.', 6),
#  'JAN 31': ('Shr', 5),
#  'DOWN': ('U.K.', 5),
#  'EIU': ('economic\\n', 2),
#  'Al-Wattari': ('Luxembourg', 2),
#  'Atlas': ('Philippines', 1),
#  'Kato': ('Japan', 6),
#  'Ecus': ('London', 2),
#  'Gerhard\n  Stoltenberg': ('U.S.', 2),
#  'Kenneth Kaunda': ('Zambia', 3),
#  'Miller': ('Vulcan', 1),
#  'Carney': ('U.S.', 2),
#  'Eishiro Saito': ('Japan', 1),
#  'Acquisition': ('Purolator', 1),
#  'Rose': ('U.S.', 2),
#  'Ronald Reagan': ('Iran', 2),
#  'Hajime Tamura': ('Japan', 8),
#  'Tamura': ('U.S.', 1),
#  'Igon': ('Spain', 4),
#  'A. William Reynolds': ('GenCorp."\\n', 1),
#  'Phillips': ('U.S.', 1),
#  'Boliden': ('Boliden', 1),
#  'Gould': ('Philadelphia', 1),
#  'Gorbachev': ('U.S.', 1),
#  'Sarney': ('an\\n', 1),
#  'Rostenkowski': ('Lane\\n  Kirkland', 2),
#  'Holmes': ('Americas', 1),
#  'Heck': ('Viner', 1),
#  'Li': ('a\\n', 2),
#  'Magma': ('Newmont', 7),
#  'Bennett': ('U.S.', 3),
#  'Ariadne': ('Manila', 2),
#  'Ferdinand Marcos': ('Cojuangco', 1),
#  'Carson': ('Welsh', 2),
#  'Stewart': ('packer\\n', 1),
#  'Jorge Cardenas': ('Europe,\\n', 1),
#  'Helmut Schlesinger': ('Tokyo', 1),
#  'Lichtblau': ('U.S.', 2),
#  'Lloyd Bentsen': ('Japan', 2),
#  'Jones': ('Vulcan', 2),
#  'Opec': ('Opec\\n', 1),
#  'SELLS STAKE': ('CANADA', 1),
#  'Javier Espinosa': ('Ecuador', 8),
#  "O'Neill": ('Germany', 1),
#  'Hall': ('The United States', 1),
#  'Stevens': ('the Red River', 1),
#  'Helmut Kohl': ('Mitterand', 1),
#  'Jose Sarney': ('U.S.', 2),
#  'Punta del Este': ('Uruguay', 4),
#  'Mario Gabelli': ('New York', 3),
#  'Hollinger': ('U.S.', 1),
#  'Davis': ('U.S.', 1),
#  'FIND': ('the Cooper Basin', 1),
#  'Plc': ('Britain', 1),
#  'Aqazadeh': ('Iran', 2),
#  'Willy De Clercq': ('U.S.', 3),
#  'Jacques Delors': ("West Germany's", 2),
#  'Shr 43': ('Shr', 1),
#  'Manuel Johnson': ('U.S.', 2),
#  'Kobena Erbynn': ('Ghana', 2),
#  'Dan Rostenkowski': ('if\\n', 1),
#  'YEAR': ('Shr', 6),
#  'Aziz': ('Pakistan', 1),
#  'CURRENCIES': ('U.S.', 4),
#  'Soros': ('Curacao', 2),
#  'Zico': ('Bancroft', 1),
#  'Balletto': ('South America', 1),
#  'Mark IV': ('a\\n', 1),
#  'Gleske': ('and\\n', 2),
#  'Bayou': ('dlrs\\n', 1),
#  'Proxmire': ('know\\n', 1),
#  'Gilberto Arango': ('Colombia', 6),
#  'Barley': ('the\\n', 1),
#  'Ward McCarthy': ('U.S.', 1),
#  'James Goldsmith': ('a\\n', 1),
#  'Goodyear': ('the\\n', 1),
#  'Blair': ('Nova', 1),
#  'Shr 37': ('mths\\n', 2),
#  'Maki': ('Japan', 4),
#  'Brian Mulroney': ('Arctic', 1),
#  'Zimmerman': ('U.S.', 3),
#  'Frans Andriessen': ('the\\n', 1),
#  'Carl Lindner': ('Cincinnati', 2),
#  'Colombo': ('Sri Lanka', 1),
#  'Herbert': ('Britain', 1),
#  'Glenn': ('U.S.', 2),
#  'D-Kan': ('dlrs\\n', 1),
#  'Perelman': ("Revlon\\'s\\n", 1),
#  'Fildes': ('North America', 1),
#  'Petromin': ('Saudi Arabia', 1),
#  'Sanford Margoshes': ('U.S.', 4),
#  'van Horick': ('Brazil', 1),
#  'Reed': ('U.S.', 1),
#  'Denis Bra Kanon': ('a\\n', 1),
#  'Rafsanjani': ('U.S.', 1),
#  'Patrick Leahy': ('(D-Vt', 2),
#  'Mikhail Gorbachev': ('the Soviet Union', 1),
#  'Thatcher': ('U.S.', 1),
#  'McIntyre': ('Alberta', 2),
#  'Taylor': ('l986.\\n', 1),
#  'CARGILL U.K.': ('U.K.', 2),
#  'NOTE:1985': ('dlrs\\n', 1),
#  'Lewis': ('Britain', 1),
#  'Walsh': ('Claremont', 1),
#  'De Clercq': ('China', 2),
#  'Kay': ('reply\\n', 1),
#  'van Driel': ('London', 1),
#  'Malcolm\n  Baldrige': ('U.S.', 5),
#  'Tigrel': ('Turkey', 2),
#  'Roach': ('U.S.', 3),
#  'Guinn': ('U.S.', 1),
#  'Sheikh Ali': ('Kuwait', 3),
#  'Almir Pazzionotto': ('Rio de Janeiro', 1),
#  'Norstar': ('New York', 2),
#  'Sugarman': ('Angeles', 1),
#  'Meinhardt': ('Linde', 1),
#  'Michael Smith': ('Japan', 1),
#  'Makoto Kuroda': ('U.S.', 3),
#  'Soriano': ('San Miguel', 1),
#  'Roberts': ('and\\n', 1),
#  'ACQUISITIONS': ('recently,\\n', 1),
#  'Entre Rios': ('Santa Fe', 3),
#  'Andreas Papandreou': ('Turkey', 3),
#  'Gholamreza Aqazadeh': ('London', 1),
#  'Claus Koehler': ('Berlin', 2),
#  'Tanaka': ('future,\\n', 2),
#  'Keidanren': ('Fumio', 1),
#  'Cargill': ('India', 2),
#  'SURPLUS': ('SPAIN', 1),
#  'LAWSON': ('U.K.', 4),
#  'Beryl Sprinkel': ('U.S.', 3),
#  'O.O.P-D': ('E.O.A', 3),
#  'Named-A': ('E.O.A', 1),
#  'Domes': ('29.60\\n', 1),
#  'Gross': ('Domestic', 1),
#  'Bentsen': ('Canada', 2),
#  'Corona': ('Corona', 4),
#  'Hecla': ('Giant Bay Resources\\n  Ltd', 1),
#  'Kahn': ('records\\n', 1),
#  'Nelson': ('British Columbia', 1),
#  'Allan Leslie': ('U.S.', 1),
#  'Espinosa': ('Ecuador', 2),
#  "Crazy Eddie's": ('Antar', 1),
#  'Shr 32': ('Shr', 2),
#  'Bilzerian': ('someone\\n', 1),
#  'MEES': ('OMAN', 1),
#  'DELAYED': ('IVORY COAST', 1),
#  'Duffour': ('Spain', 2),
#  'Aga': ('Duffour', 3),
#  'Kohl': ('Poehl', 1),
#  'Alan Greenspan': ('U.S.', 2),
#  'Treasurer Paul Keating': ('forecast\\n', 2),
#  'Sanford C. Bernstein': ('Sanford C. Bernstein', 1),
#  'Laidlaw': ('U.S.', 1),
#  'Lim Keng Yaik': ('Malaysia', 2),
#  'Drake': ('China', 1),
#  'Carey': ('China', 1),
#  'Cardenas': ('Europe,\\n', 1),
#  'Note': ('dlrs\\n', 5),
#  'Wright': ('Texas', 2),
#  'Hoare Govett': ('U.S.', 1),
#  'Yaacobi': ('Israel', 4),
#  'Chang Chi-cheng': ('Washington', 1),
#  'Norsk Hydro': ('a\\n', 1),
#  'Anderson': ('Welsh', 2),
#  'Martin Sosnoff': ('New York', 2),
#  'Tadashi Kuranari': ('Japan', 3),
#  'Thyssen': ("West Germany.\\n      '", 1),
#  'Rev': ('Shr', 4),
#  'JAN': ('U.S.', 8),
#  'Viermetz': ('U.S.', 2),
#  'Dry': ('Queensland', 1),
#  'De Mel': ('Sri Lanka', 1),
#  'Amylum': ('Britain', 1),
#  'Michael Jopling': ('West Germany', 1),
#  'Wolf': ('U.S.', 2),
#  'Pat Roberts': ('Kansas', 1),
#  'Michael': ('Tokyo', 2),
#  'WestLB': ('Luxembourg', 1),
#  'Ranks Hovis': ('Avana', 1),
#  'BUYS STAKE': ('the\\n', 1),
#  'Pope': ('North America', 1),
#  'Marion': ('cause\\n', 1),
#  'Douglas': ('year\\', 1),
#  'Robert Ortner': ('U.S.', 2),
#  'Zack': ('dlrs\\n', 1),
#  'Iida': ('a\\n', 1),
#  'Silas': ('Norway', 1),
#  'Mike Moore': ('a\\n', 2),
#  'McIvor': ('the Middle East', 1),
#  'Growmark': ('Ill.', 1),
#  'Chapman': ('due\\n', 1),
#  'Troon': ("the\\n  company's", 3),
#  'Abu al-Bukhoosh': ('Gulf', 1),
#  'Kadoorie': ('Kadoorie', 1),
#  'Mutsuki Kato': ('U.S.', 2),
#  'Shintaro Abe': ('U.S.', 5),
#  'Samuel Heyman': ('U.S.', 1),
#  'J.P. Morgan': ('Brazil.\\n', 1),
#  'Murray': ('dlrs\\n', 1),
#  'Turgut Ozal': ('Turkey', 1),
#  'Allen Wallis': ('U.S.', 2),
#  'Kohlberg Kravis Roberts': ('Texas', 1),
#  'Ghanaian': ('London', 1),
#  'Said': ('U.S.', 2),
#  'Zondervan': ('London', 1),
#  'Interim': ('583.83', 1),
#  'Kiichi\n  Miyazawa': ('Paris', 1),
#  'Nortek': ('Rexham', 3),
#  'Parana': ('Paulo,', 1),
#  'Shr 69': ('3,808,000\\n', 1),
#  'PRICES': ('dlr\\n', 1),
#  'Nerco': ('Operation', 1),
#  'Vincent Siew': ('Washington', 4),
#  'David Annesley': ('New York', 2),
#  'Michel Noir': ('New Zealand', 2),
#  'Merlin': ('Basin', 1),
#  'Irwin Jacobs': ('Minneapolis', 1),
#  'Nichols': ('be\\n', 1),
#  'Richard Darman': ('U.S.', 3),
#  'Scott': ('dlrs\\n', 1),
#  'Huron': ('Erie', 1),
#  'Resdel': ('San/Bar', 4),
#  'al-Qabas': ('Kuwait', 2),
#  'Wilson': ('U.S.', 1),
#  'Natalie Koether': ('N.J.', 3),
#  'Yasuhiro': ('Washington', 1),
#  'Jose Romero': ('Brussels', 1),
#  'Valor': ('dlrs\\n', 1),
#  'Allan Hawkins': ('ETL', 2),
#  'Helmut Schmidt': ('West Germany', 2),
#  'Kuwait': ('U.S.', 3),
#  'Hawkins': ('BIL\\', 1),
#  'GREENSPAN': ('U.S.', 2),
#  'Western': ('U.K.', 1),
#  'Ansett': ('the United States', 1),
#  'Bass Strait': ('Cooper', 1),
#  'Skeoch': ('Capel\\', 2),
#  'Seger': ('gross\\n', 1),
#  'VOTE': ('10.\\n', 1),
#  'Chang': ('U.S.', 1),
#  'Top': ('U.K.', 8),
#  'Apex': ('exchange,\\n', 1),
#  'Dayton-Hudson': ('Minneapolis', 1),
#  'Malawi': ('Tanzania', 4),
#  'Rosario Ilacqua': ('L.F.', 1),
#  'Jon Rosenbaum': ('U.S.', 4),
#  'Note:': ('dlrs\\n', 1),
#  'James Capel': ('London', 1),
#  'Shr 53': ('NET\\n', 1),
#  'Adams': ('U.S.', 1),
#  'ISSUES': ('U.S.', 2),
#  'Reid': ('North Sea', 1),
#  'Comissaria Smith': ('Comissaria', 1),
#  'Margoshes': ('Saudi Arabia', 2),
#  'Guillaume': ('France', 2),
#  'European Sugar': ('France', 2),
#  'PACT': ('Columbus', 1),
#  'BHP': ('900\\n', 1),
#  'Anger': ('Japan', 2),
#  'Rothschild': ('U.S.', 1),
#  'Peter Baron': ('Germany', 1),
#  'Krenzler': ('Oklahoma', 1),
#  'Glass': ('and\\n', 1),
#  'Gephardt': ('States', 2),
#  'HAD': ('RO', 1),
#  'Corpus Christi': ('Texas', 3),
#  'Bird': ('and\\n', 1),
#  'Jordan': ('Tunisia', 1)}

# %%
most_freq_persons_associated_with_locations
# Out:
# {'U.S.': ('the\\n', 107),
#  'Shr': ('mln\\n', 262),
#  'Japan': ('Reagan', 49),
#  'U.K.': ('LAWSON', 16),
#  'Brazil': ('the\\n', 12),
#  'the United States': ('the\\n', 18),
#  'Paris': ('Baker', 15),
#  'Canada': ('by\\n', 8),
#  'China': ('mln\\n', 8),
#  'Washington': ('the\\n', 10),
#  'London': ('Lawson', 5),
#  'West Germany': ('the\\n', 11),
#  'New York': ('the\\n', 7),
#  'Taiwan': ('by\\n', 5),
#  'Iran': ('the\\n', 13),
#  'Britain': ('Lawson', 8),
#  'Gulf': ('Reagan', 16),
#  'JAPAN': ('an\\n', 3),
#  'Tokyo': ('the\\n', 8),
#  'France': ('Kiichi Miyazawa', 5),
#  'Indonesia': ('the\\n', 8),
#  'Ecuador': ('Javier Espinosa', 9),
#  'Australia': ('the\\n', 11),
#  'Europe': ('he\\n', 2),
#  'Nine': ('Avg', 26),
#  'Texas': ('Jim Wright', 4),
#  'U.S': ('the\\n', 6),
#  'Italy': ('the\\n', 4),
#  'the Soviet Union': ('Reagan', 7),
#  'Saudi Arabia': ('Nazer', 9),
#  'South Korea': ('the\\n', 4),
#  'Iraq': ('the\\n', 4),
#  'Avg': ('mln\\n', 89),
#  'Malaysia': ('the\\n', 3),
#  'India': ('Cargill', 3),
#  'Kuwait': ('Kuwait', 9),
#  'Colombia': ('Gilberto Arango', 5),
#  'Spain': ('Igon', 3),
#  'USSR': ('the\\n', 3),
#  'CANADA': ('0.4', 2),
#  'California': ('NASS', 2),
#  'Moscow': ('the\\n', 6),
#  'Hong Kong': ('the\\n', 3),
#  'Venezuela': ('Javier Espinosa', 4),
#  'Thailand': ('the\\n', 4),
#  'Singapore': ('are\\n', 2),
#  'Turkey': ('Papandreou', 5),
#  'Philippines': ('an\\n', 2),
#  'The United States': ('an\\n', 2),
#  'CHINA': ('TONNES', 4),
#  'United States': ('Yasuhiro Nakasone', 2),
#  'South Africa': ('an\\n', 3),
#  'Chicago': ('the\\n', 2),
#  'Mexico': ('Gurria', 4),
#  'Norway': ('an\\n', 4),
#  'New Zealand': ('Yeutter', 4),
#  'Greece': ('Papandreou', 2),
#  'Netherlands': ('by\\n', 2),
#  'Argentina': ('Yeutter', 3),
#  'Egypt': ('TONNES CORN', 1),
#  'Pakistan': ('mln\\n', 3),
#  'Revs': ('mln\\n', 23),
#  'Belgium': ('the\\n', 3),
#  'Peru': ('zinc\\n', 2),
#  'Houston': ('John', 1),
#  'Ohio': ('by\\n', 4),
#  'Florida': ('boxes,\\n', 2),
#  'Sweden': ('Wallenberg', 2),
#  'Bonn': ('the\\n', 7),
#  'Portugal': ('the\\n', 3),
#  'Germany': ('Poehl', 3),
#  'Algeria': ('the\\n', 2),
#  'UK': ('the\\n', 2),
#  'Switzerland': ('the\\n', 3),
#  'BRAZIL': ('CONTINUE STRIKE', 2),
#  'Calif.': ('Richfield', 2),
#  'DIV': ('Record', 2),
#  'Dallas': ('Harold Simmons', 3),
#  'Bahrain': ('Bahrain', 4),
#  'US': ('Aarnoud Loudon', 2),
#  'Denmark': ('deterioration\\n', 1),
#  'Africa': ('Hans Coebergh', 1),
#  'TAIWAN': ('TONNES', 2),
#  "West Germany's": ('Baker', 2),
#  'Mths': ('mln\\n', 16),
#  'the United\n  States': ('Gephardt', 2),
#  'Quebec': ('Quebec', 4),
#  'Nigeria': ('Lukman', 3),
#  'Uruguay': ('Punta del Este', 6),
#  'N.J.': ('Natalie Koether', 3),
#  'Frankfurt': ('James Baker', 4),
#  'West\n  Germany': ('West\\n', 8),
#  'Kenya': ('Robert Ouko', 2),
#  'Qatar': ('Lukman', 2),
#  'Oklahoma': ('Henry Bellmon', 1),
#  "South Korea's": ('Kim', 3),
#  'America': ('Reagan', 2),
#  'Zambia': ('Kenneth Kaunda', 3),
#  'Michigan': ('mln\\n', 2),
#  'Illinois': ('Rostenkowski', 3),
#  'Venice': ('Reagan', 4),
#  'Louisiana': ('Huckaby', 3),
#  'Tehran': ('Reagan', 3),
#  'N.Y.': ('RISE 523', 2),
#  'ECUADOR': ('Fernando Santos Alvite', 3),
#  'Poland': ('barley,\\n', 1),
#  'Asia': ('Cornelissen', 1),
#  'Los Angeles': ('the\\n', 2),
#  'North Sea': ('Lawson', 2),
#  'Div': ('mln\\n', 6),
#  'North America': ('mln\\n', 3),
#  'FRANCE': ('SELLS YEN - DEALERS\\n', 2),
#  'Hungary': ('Fekete', 3),
#  'INDIA': ('RBI,\\n', 1),
#  'Israel': ('Yaacobi', 4),
#  'Cuba': ('the\\n', 2),
#  'Piedmont': ('David Shipley', 1),
#  'Fla.': ('Fla.,\\n', 3),
#  'Ontario': ('Mill City\\n', 2),
#  'Zimbabwe': ('DEVALUATION - CENTRAL BANK\\n', 2),
#  'Kansas': ('Duluth', 1),
#  'Luxembourg': ('Al-Wattari', 2),
#  'Portland': ("Reebok's\\n", 2),
#  'Sri Lanka': ('the\\n', 2),
#  'Peking': ('are\\n', 2),
#  'Soviet Union': ('Reagan', 3),
#  'Mthly': ('Pay', 23),
#  'the Middle East': ('McIvor', 2),
#  'Korea': ('C. Manly Molpus', 2),
#  'Cominco': ('Lornex', 5),
#  'West': ('West\\n', 5),
#  'The Soviet Union': ('Iran', 1),
#  'Bolivia': ('Bolivia', 4),
#  'Alberta': ('McIntyre', 2),
#  'Geneva': ('Punta del Este', 2),
#  'Toronto': ('the\\n', 2),
#  'Vienna': ('production\\n', 2),
#  'Alaska': ('Hodel', 2),
#  'LONDON': ('SAY\\n', 1),
#  "South Africa's": ('the\\n', 2),
#  'Minnesota': ('Rudy Perpich', 2),
#  'Iowa': ('Iowa Beef', 3),
#  'Vancouver': ('Sullivan', 4),
#  'Ghana': ('an\\n', 6),
#  'Jordan': ('Jordan', 4),
#  "New Zealand's": ('deficit\\n', 3),
#  "Saudi Arabia's": ('Hisham', 2),
#  'Petrobras': ('Petrobras', 8),
#  'Seoul': ('Huh Sun-yong', 2),
#  'Finland': ('Raision Tehtaat', 2),
#  'IRAN': ('SILKWORM MISSILE', 2),
#  'Hamburg': ('gross\\n', 1),
#  'Yugoslavia': ('De Clercq', 1),
#  'New Jersey': ('Sosnoff', 1),
#  'Ill.': ('Maytag', 2),
#  'Pacific': ('Balao', 6),
#  'Uganda': ('Uganda', 2),
#  'Chile': ('cooperation\\n', 1),
#  'Delaware': ('the\\n', 3),
#  'Brussels': ('Jose Romero', 1),
#  'Missouri': ('Richard Gephardt', 3),
#  'Queensland': ('Moonie', 2),
#  'Sealy': ('mln\\n', 4),
#  'Minneapolis': ('Duluth', 3),
#  'UAE': ('the\\n', 2),
#  'Philadelphia': ("Crazy Eddie's", 1),
#  'First City': ('J.A. Elkins', 3),
#  'Utah': ('Garn', 1),
#  'Ivory Coast': ('Senegal', 1),
#  'Midwest': ('Mohler', 1),
#  'West Texas': ('Mohler', 1),
#  'Morocco': ('CCC', 2),
#  'Delhi': ('Kelman', 3),
#  'Mediterranean': ('dlrs,\\n', 1),
#  'Year': ('Year\\n', 11),
#  'SAUDI ARABIA': ('COMMITMENT', 2),
#  'Costa Rica': ('van Horick', 1),
#  'ETL': ('Monier', 4),
#  'Austria': ('gross\\n', 1),
#  'Watanabe': ('Watanabe', 4),
#  'MARKET': ('53 MLN STG', 1),
#  'Montreal': ('Dominion', 1),
#  'Atlantic': ('Houssels', 1),
#  'British Columbia': ('Northair', 2),
#  'IRAQ': ('AHMED TAQI REPLACED', 4),
#  'Zurich': ('Theodor Stadelmann', 2),
#  'E.O.A': ('Unnamed-B', 13),
#  'the United Arab Emirates': ('Khor Fakkan', 1),
#  'Newmont': ('Magma', 8),
#  'Indiana': ('Richard Lugar', 2),
#  'Pennsylvania': ('by\\n', 1),
#  'Colorado': ('Dale Mohler', 1),
#  'Sudan': ('mln\\n', 1),
#  'Manila': ('Corazon Aquino', 2),
#  'Honduras': ('Cuenca', 1),
#  'COLOMBIA': ('Gilberto Arango', 1),
#  'San Francisco': ('Meinert', 1),
#  'Shanghai': ('Xu Jinfeng', 1),
#  'SPAIN': ('Bank\\n', 1),
#  'Papua New Guinea': ('Merlin', 2),
#  'Virginia': ('the\\n', 1),
#  'Lyng': ('an\\n', 2),
#  'Western Europe': ('the\\n', 2),
#  'Oman': ('MEES)\\n', 1),
#  'Ottawa': ('Allegis', 1),
#  'AUSTRALIA': ('performance,\\n', 1),
#  'New': ('York', 4),
#  'Tunisia': ('Tunisia', 4),
#  'City': ('Houssels', 1),
#  'Nevada': ('Sosnoff', 2),
#  'Purolator': ('Purolator', 2),
#  'Qtrly': ('Record', 7),
#  'N.A.': ('Domes', 2),
#  'Denver': ('judge\\n', 2),
#  'Middle East': ('23 mln\\n', 1),
#  'Mideast': ('Khafji', 1),
#  'Oregon': ('Mark Hatfield', 1),
#  'Pertamina': ('Abdul Rachman Ramly', 2),
#  'Sydney': ('the\\n', 1),
#  'Poehl': ('Poehl', 6),
#  'Cordoba': ('Buenos Aires', 5),
#  'Athens': ('Andreas Papandreou', 2),
#  'EGYPT': ('TONNES CORN', 1),
#  'Calgary': ('yet\\n', 2),
#  'Jersey': ('Ernest Saunders', 3),
#  'Arizona': ('Joske', 1),
#  'Wisconsin': ('Toby', 1),
#  'Libya': ('an\\n', 1),
#  'Ireland': ('points\\n', 1),
#  'Tanzania': ('Malawi', 4),
#  'Jakarta': ('Mochtar Kusumaatmadja', 1),
#  'Rotterdam': ('Han Lammers', 1),
#  'SOUTH KOREA': ('SURPLUS', 1),
#  'Sao Paulo': ('Parana and\\n', 1),
#  'West Berlin': ('Hiss', 1),
#  'Southwest': ('Btu', 1),
#  'New England': ('Comeau', 1),
#  'Romania': ('Reagan', 3),
#  'Connecticut': ('Trans-Lux', 1),
#  'Maryland': ('Chirac', 1),
#  'the North Sea': ('gas\\n', 1),
#  'Pa.': ('Charles Cheleden', 1),
#  'Georgia': ('Dominion', 1),
#  'Nicaragua': ('van Horick', 1),
#  'Mississippi': ('Ron Burgess', 1),
#  'Akron': ('the\\n', 3),
#  "Hong Kong's": ('Li', 1),
#  'New South Wales': ('Moonie', 1),
#  'South America': ('Balletto', 1),
#  'the Far East': ('Baldrige', 1),
#  'Amsterdam': ('Frits van', 1),
#  'Inc': ('Inc', 4),
#  'the Gulf of Mexico': ('pct,\\n', 1),
#  'Atlanta': ('Meinert', 1),
#  'TOKYO': ('ACTIVELY BUYS DOLLARS', 2),
#  'the Netherlands': ('nil,\\n', 1),
#  'Miami': ('Kahn', 1),
#  'Toledo': ('Duluth', 1),
#  'Boston': ('Boston', 1),
#  'HONG KONG': ('REAGAN', 1),
#  'Guatemala': ('Milds', 1),
#  'Cleveland': ('Alan Clements', 1),
#  'Bangladesh': ('DIESEL', 1),
#  'Nebraska': ('Mohler', 2),
#  'South': ('James Baker', 1),
#  'Redland': ('Tim Cohen', 2),
#  'England': ('Isis', 1),
#  'SINGAPORE': ('Lee Hsien Loong', 1),
#  'O.O.P': ('Unnamed-B', 8),
#  'Zaire': ('Malawi', 2),
#  'Rhode Island': ('Dudley Taft', 1),
#  'Fort Worth': ('Bass', 2),
#  'West Texas Sour': ('West\\n', 1),
#  'Memphis': ('Southeastern', 1),
#  'Alabama': ('Ron Burgess', 1),
#  'Latin America': ('Scholl', 1),
#  'Tenn.': ('Ball', 1),
#  'Minstar': ('Irwin L. Jacobs', 1),
#  'MTHS': ('Oper', 6),
#  'the U.S. Gulf': ('Sour', 1),
#  'Phoenix': ('Martin S. Ackerman', 2),
#  'New Orleans': ('Consolidated', 2),
#  'Fiji': ('Capitaine Wallis', 1),
#  'Ore.': ('Harris Pine\\n', 1),
#  'SHARPLY': ('Gerhard de Kock', 1),
#  'Haiti': ('dlrs,\\n', 2),
#  'PHILIPPINES': ('TONNES', 1),
#  'MALAYSIA': ('the\\n', 1),
#  'Six Mths': ('Revs', 1),
#  '&': ('Hugh Fletcher', 1),
#  'Henderson': ('he\\n', 1),
#  'VENEZUELA': ('Fernando Santos Alvite', 2),
#  'Holland': ('Sales', 1),
#  'Ga.': ('an\\n', 1),
#  'Far East': ('JANUARY\\n', 1),
#  'Caracas': ('Jaime Lusinchi', 2),
#  'Rostam': ('Reagan', 1),
#  'Alcan': ('Rugeroni', 3),
#  'Managua': ('Dauster', 2),
#  'Seattle': ('Rotterdam', 1),
#  'Kansas City': ('Jonathan Braatz', 1),
#  'Rio de Janeiro': ('say\\n', 1),
#  'Sosnoff': ('the\\n', 2),
#  'San Miguel': ('Barwon', 2),
#  'Kentucky': ('Western Kentucky', 1),
#  'Atlantic City': ('Houssels', 1),
#  'Baghdad': ('Niedermeyer', 1),
#  'Detroit': ('Arvid Jauppi', 2),
#  'St. Louis': ('Meinert', 1),
#  'Henan': ("Jiangsu.\\n      '", 1),
#  'Sichuan': ("Jiangsu.\\n      '", 1),
#  'Milan': ('Stadelmann', 1),
#  'FLORIDA': ('GALS', 2),
#  'KUWAIT': ('the\\n', 2),
#  'Ariz.': ('SELLS JOINT VENTURE', 1),
#  'Cincinnati': ('Carl Lindner', 2),
#  'Pittsburgh': ('Share', 1),
#  'Va.': ('Thomas Nationwide', 1),
#  'the Gulf': ('Mike Synar', 1),
#  'Jamaica': ('Wilson', 1),
#  'Saskatchewan': ('gas\\n', 1),
#  'Johannesburg': ('Chitambala', 1),
#  'Dubai': ('Japanese\\n', 1),
#  'NORWAY': ('an\\n', 2),
#  'H.K.': ('SAY\\n  Banks', 2),
#  'Seipp': ('Commenting', 1),
#  'Avana': ('Avana', 2),
#  'Ina': ('the\\n', 1),
#  'B.C.': ('Mo', 1),
#  'BRITAIN': ('Bill Locke\\n', 1),
#  'Hawaii': ('David Lange', 1),
#  'N.C.': ('Jesse Helms', 1),
#  'BELGIUM': ('SOURCES SAY\\n', 1),
#  'Rexham': ('Nortek', 4),
#  'Midland': ('Qtr', 1),
#  'Ind': ('Ind', 5),
#  'Cotton': ('Mln Bales)\\n', 1),
#  'Massachusetts': ('Baird', 2),
#  'SANCTIONS': ('Reagan', 1),
#  'Guangdong': ('Rainfall', 1),
#  'Conn.': ('Greenery', 1),
#  'Computerland': ('an\\n', 1),
#  'Kuala Lumpur': ('the\\n', 2),
#  'Cooper Basin': ('TMOC', 2),
#  'Fujian': ('Guanghdong', 1),
#  'Prudhoe Bay': ('Hodel', 1),
#  'New Mexico': ('Durham', 1),
#  'QUOTA': ('Hernandez Grisanti', 1),
#  'Dar es Salaam': ('Dar', 2),
#  'Straits': ('Weinberger', 2),
#  'El Salvador': ('for\\n', 1),
#  'the Dominican Republic': ('Yulo', 1),
#  'the Aegean Sea': ('Andreas', 2),
#  'Syria': ('July\\n', 1),
#  'Cairo': ('Anwar Sadat', 1),
#  'Renouf': ('Mike Cashin', 2),
#  'Pinola': ('Pinola', 3),
#  'York': ('York', 4),
#  'HIKES': ('Pay', 1),
#  'S.C.': ('Marcus Schloss', 1),
#  'Northeast': ('following\\n', 2),
#  'ACQUISITION': ('education\\n', 1),
#  'Minn.': ('Details', 1),
#  'Anhui': ("Jiangsu.\\n      '", 1),
#  'San Diego': ('than\\n', 1),
#  "Sri Lanka's": ('CUT\\n', 1),
#  'South\n  Africa': ("Africa.\\n      '", 1),
#  'Belgrade': ('Subotica', 1),
#  'Puerto Rico': ('Mayaguez', 1),
#  'E.C.': ("E.C.        '", 1),
#  'New\n  York': ('York', 2),
#  'M-1': ('M-2', 2),
#  'the Strait of Hormuz': ('Khor Fakkan', 1),
#  'the\n  Gulf': ('Khor Fakkan', 1),
#  'South Dakota': ('Huron Dressed Beef', 2),
#  'Calif': ('Richfield', 2),
#  'Manhattan': ('Harcourt', 1),
#  'Jacksonville': ('Fla.,\\n', 1),
#  'Caribbean': ('Cano Limon', 1),
#  'YR': ('mln\\n', 3),
#  'Maine': ('Suffield', 1),
#  'Saudi\n  Arabia': ('Boliden', 1),
#  'Arabia': ('Azzam', 1),
#  'Ethiopia': ('Malawi', 1),
#  'Southeast Asia': ('Lin', 1),
#  'Dayton Hudson': ('the\\n', 2),
#  'Lebanon': ('Jordan\\n', 1),
#  'Ultramar': ('Ultramar', 1),
#  '11.6': ('mln\\n', 2),
#  'East': ('the\\n', 1),
#  'Pantera': ('Amex\\n', 1),
#  'Indianapolis': ('Bedell', 1),
#  'Persian Gulf': ('Herrington', 2),
#  'Cornelissen': ('Asia\\n', 1),
#  'Osaka': ('Yeutter', 2),
#  'North Yemen': ('are\\n', 1),
#  'Cojuangco': ('Ferdinand Marcos', 1),
#  'Shr 10': ('mln\\n', 1),
#  'Shr 58': ('mln\\n', 2),
#  'Brasilia': ('Leonardo Brito', 1),
#  'Montedison': ('committee,\\n', 1),
#  'Burlington': ('Dominion', 2),
#  'D-Tex': ('Charles Stenholm', 2),
#  'Record': ('Note', 1),
#  'Hebei': ("Jiangsu.\\n      '", 1),
#  'the Great Lakes': ('Grain', 1),
#  'SOVIET UNION': ('Nikolai Talyzin', 1),
#  'New York City': ('City\\n', 1),
#  'Ugandan': ('Long', 1),
#  'HUNGARY': ('HUNGARY\\n', 1),
#  'Goldendale': ('at\\n', 2),
#  'Quito': ('Mercalli', 1),
#  'R.I.': ('Gelch', 1),
#  'NEW ZEALAND': ('CONTINUE FIRM MONETARY', 1),
#  'Hong\n  Kong': ('Elliott Burnside', 1),
#  'MOSCOW': ('THATCHER', 1),
#  'Heidrun': ('Statoil', 1),
#  'Riyadh': ('Hisham', 2),
#  'Columbia': ('Stanadyne', 1),
#  'Periods': ('mln\\n', 3),
#  'Colo.': ('Michael Krupp', 1),
#  'Los\n  Angeles': ('mln\\n', 1),
#  'Arkansas': ('Ron Burgess', 1),
#  'Bra Kanon': ('Bra Kanon', 4),
#  'Bass Strait': ('Bass Strait', 2),
#  'Chernobyl': ('Thomson', 1),
#  "First City's": ('It\\', 1),
#  'CHICAGO': ('UP', 1),
#  'Diamond Shamrock': ('Roger Hemminghaus', 1),
#  'Istanbul': ('Almaden', 1),
#  'Slifer': ('M-2', 1),
#  'Boddington': ('Ora Banda', 1),
#  'Terra Nova': ('Bob Foulkes', 1),
#  'Dakota City': ('Allen Zack', 1),
#  'INTERVENE': ('MIYAZAWA', 2),
#  'Oslo': ('Bjoern Sejerstad', 1),
#  'Neptunia': ('by\\n', 1),
#  'Nashville': ('Cain-Sloan', 1),
#  'Providence': ('Gelch', 1),
#  'RAPESEED': ('Oilseed', 1),
#  'the United Kingdom': ("Denys Henderson.\\n      '", 1),
#  'Vulcan': ('Jones', 3),
#  'Antwerp': ('Severel', 1),
#  'BRUSSELS': ('TONNES', 2),
#  'Mississippi River': ('ADM Growmark', 1),
#  'Minn': ('Arlan Stangeland', 2),
#  'Lubbock': ('Dale Mohler', 1),
#  'DOME': ('MAY SHORT-CIRCUIT', 2),
#  'Munich': ('Arthur Krumper', 1),
#  'Lisbon': ('EPAC', 3),
#  'Idaho': ('Hecla', 2),
#  '1.58': ('mln\\n', 3),
#  'Jeddah': ('Barley', 1),
#  'the Mideast Gulf': ('George Shultz', 1),
#  'Santa Barbara': ('Reagan', 1),
#  'Bombay': ('the\\n', 1),
#  'Miss.': ('Borden', 1),
#  'Salt Lake City': ('the\\n', 1),
#  'the Red River': ('Stevens', 2),
#  'Antar': ('Crazy Eddie', 2),
#  'Guangxi': ('Guanghdong', 1),
#  'Victoria': ('Capitaine Wallis', 1),
#  'Baltimore': ('Carteret', 2),
#  'Rio de\n  Janeiro': ('Janeiro', 4),
#  'Wyoming': ('BUYS MINERAL RIGHTS\\n', 1),
#  'West Virginia': ('Allegheny', 1),
#  'Perelman': ('James Goldsmith', 1),
#  'Iceland': ('Arne Oeien', 1),
#  'BPCC': ('BPCC', 2),
#  'Dublin': ('Richfield', 2),
#  'South Australia': ('Norgold', 1),
#  'Alexandria': ('Mana Said al-Oteiba\\n', 1),
#  'Mousavi': ('because\\n', 1),
#  'Columbus': ('Strata', 1),
#  'Market': ('Coloroll', 1),
#  'Tampa': ('Fla.,\\n', 2),
#  'GREECE': ("GREECE REPEATS'", 1)}

# %% [markdown]
# ### Output Analysis

# %% [markdown]
# ##### Here I identified the most frequent location cooccurred with a certain person in the same sentences and vice versa. From the output above, for example, the name "Reagan" cooccurred with "U.S." most and it's 99 times. Similar cases exist like "Yasuhiro Nakasone" and "Japan", "James Baker" and "U.S.", which all make a lot of sense. However, the output for my second dictionary is not ideal, where I need to get rid of the noisy words.
# ##### If I was given further time, I will do two things: First, I want to consider all frequent terms rather than top 3, although under many cases top 3 would be enough. Second, I will go back and figure out how to improve my code to be able to get rid of the noisy words showing up in my "most_freq_persons_associated_with_locations".
#
# ##### Thank you! Best, Guangji.
